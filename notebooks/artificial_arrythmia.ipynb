# %% [markdown]
# # Optical Gating Alignment Algorithms
#
# ## Scope of this Notebook
#
# This notebook accompanies our python module for optical gating reference period alignment algorithms: optical_gating_alignment, which can be found at https://github.com/Glasgow-ICG/optical-gating-alignment.
#
# If you have downloaded the repository from the above link then everything required for this notebook should be in the right place.
# This includes a data set that contains 30 multipage .tif files showing example reference heartbeats collected every approx. 15 minutes during a real adaptive optical gating timelapse experiment. This data folder also includes two .csv data files.
# One with the determined period, timestamp and drift for each reference set.
# One with manually identified target frames for each reference set from five different scorers.
#
# This notebook will install the optical_gating_alignment module in your Python environment using pip.
# If you do not want this you should edit the notebook first.
#
# The purpose of this notebook is to produce a demonstration of the quality of synchronisation algorithms. Specifically:
#
# * A plot of the stability of different algorithms for adaptive optical gating-based phase-locking by comparing human and computational derived target frames, i.e. figure 3b. Please note that neither the human or computational derived targets can be considered 'ground truths' and are compared to indicate stability not precision/accuracy.
# * 'Flick books', each showing the phase-lock over time (compared to the mean manual result) for different algorithms
#
# For users interested in following the outputs of our adaptive optical gating systems, i.e. the phase-locked target frame, we draw their attentions to the lines that call the `oga.process_sequence()` function, particularly the output variable `global_roll_factor`.
#
# ## Related Publications
#
# * TODO
# * TODO
# * TODO

# %% [markdown]
# ## Import Modules

# %%
import os

# Numpy, Scipy, Pandas and Scikits
import numpy as np
import pandas as pd
from skimage import io

# Matplotlib and Seaborn
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib widget

# Install Package
# !pip install optical_gating_alignment # TODO publish
# !poetry build
# !pip install --no-deps --ignore-installed ../dist/optical_gating_alignment-2.0.0-py3-none-any.whl  # stupidly this is not this venv
import optical_gating_alignment.optical_gating_alignment as oga
oga.set_logger(level="SUCCESS", format="jupyter")  # change to "WARNING", "INFO" or "DEBUG" for more information

print('Fin')
# Out:
# Building optical-gating-alignment (2.0.0)
#  - Building sdist
#  - Built optical-gating-alignment-2.0.0.tar.gz
#
#  - Building wheel
#  - Built optical_gating_alignment-2.0.0-py3-none-any.whl
# Defaulting to user installation because normal site-packages is not writeable
# Processing /home/chas/git/optical-gating-alignment/dist/optical_gating_alignment-2.0.0-py3-none-any.whl
# Installing collected packages: optical-gating-alignment
# Successfully installed optical-gating-alignment-2.0.0
# Fin

# %% [markdown]
# ## Local Functions

# %%
def circularMean(anglesInRad,axis=1):
    '''In order to deal with the wrapped nature of the data we're dealing with, this function works out the angular or circular mean.
    It is very important to note that the values must be in radians for this to work.'''
    x = np.nansum(np.cos(anglesInRad),axis=axis)
    y = np.nansum(np.sin(anglesInRad),axis=axis)
    return np.arctan2(y,x)%(2*np.pi)


def circularMeanScaled(values,divisor,axis=1):
    '''Wrapper function that takes any values and their divisors, converts them to radians and calculates the circular mean.'''
    # Convert to radians
    radians = 2*np.pi*values/divisor
    return circularMean(radians,axis=axis)*divisor/(2*np.pi)

print('Fin')
# Out:
# Fin

# %% [markdown]
# ## Load Reference Information
#
# Here we load some provided information about the time series from `periods.txt`. Each row contains six entries:
# * reference `Number` (i.e. sequence order)
# * `Period` length (in frames)
# * reference heartbeat image drift in X (`Drift_X`)
# * and `Drift_Y`
#
# The first row should contain headers (that ideally match the above).
#
# Note that the period length, timestamp and drift are all contained in `period.txt` an output of the main software that can be found with the reference heartbeat images. We have only compiled this information into a single file for demonstration purposes.

# %%
root = "./local-data"

periods = pd.read_csv(os.path.join(root,"periods.csv"),
                      sep=',',
                      header=0,
                      index_col=0,
                      names=['Number','Period','Drift_X','Drift_Y'])

# Initialise columns for algorithms
algorithms = ['Adaptive','Dynamic','SuperDynamic']
for alg in algorithms:
    periods[alg] = np.nan

# display(periods.head(5))

print('Fin')
# Out:
# Fin

# %% [markdown]
# ## Load Manual Results
#
# If manual results are not available, i.e. if you're using data that is not the provided example, sets a flag. All plots and flick books will then be absolute rather than relative to the manually derived results.

# %%
if os.path.exists(os.path.join(root,"scores.csv")):
    # For quick reference to all human scorers
    scorers = ['CJN','JT','CB','AB','FB']

    # Load manual results as pd.DataFrame
    humanScores = pd.read_csv(os.path.join(root,"scores.csv"),
                          sep=',',
                          header=0,
                          index_col=0,
                          names=['Number']+scorers)
#     display(humanScores.sample(5))

    # determine starting period
    # we always start with the first human scores given
    # so we can pick a good initial target
    start = humanScores.index[0]
    periods = periods.loc[start::5,:]
    periods.drop(140)

    # Merge with periods.csv data
    results = periods.join(humanScores,how='outer')
#     display(results)

    # Identify consensus start in frames (using a circular mean)
    initialTarget = circularMeanScaled(results[scorers].dropna().iloc[0].values,results['Period'].dropna().iloc[0],axis=0)
    print('Intial target: {0} frames'.format(initialTarget))

    # Convert Frames to Radians
    for scorer in scorers:
        results[scorer] = (2*np.pi*(results[scorer]/results['Period']))%(2*np.pi)

    # Calculate mean 'scorer'
    means = circularMean(results[scorers],axis=1)
    
    # Shift to difference from mean
    for scorer in scorers:
        results[scorer] = results[scorer]-means

    # Fix wrapping issues
    results[scorers] = np.where(results[scorers]<-np.pi,results[scorers]+(2*np.pi),results[scorers])
    results[scorers] = np.where(results[scorers]>np.pi,results[scorers]-(2*np.pi),results[scorers])

#     display(results.head(10))
    
    # set flag
    relative_to_manual = True
else:
    # set flag
    relative_to_manual = False
    results = periods.copy()
    initialTarget = circularMean([0.0], axis=0)  # toy initial target of 0.0
    
display(results.head(10))

print('Fin')
# Out:
# Intial target: 13.597565048856001 frames
#            Period  Drift_X  Drift_Y  Adaptive  Dynamic  SuperDynamic  \
# Number
# 90      34.282163        0        0       NaN      NaN           NaN
# 95      34.616525        0        0       NaN      NaN           NaN
# 100     34.261581        0        0       NaN      NaN           NaN
# 105     34.051320        0        0       NaN      NaN           NaN
# 110     34.119740        0        0       NaN      NaN           NaN
# 115     34.672674        0        0       NaN      NaN           NaN
# 120     34.720043        0        0       NaN      NaN           NaN
# 125     35.019437        0        0       NaN      NaN           NaN
# 130     34.904905        0        0       NaN      NaN           NaN
# 135     34.565785        0        0       NaN      NaN           NaN
#
#                  CJN            JT            CB            AB            FB
# Number
# 90      2.570363e-01 -1.095209e-01 -1.095209e-01  7.375770e-02 -1.095209e-01
# 95      0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 100    -3.657890e-02 -3.657890e-02 -3.657890e-02  1.468098e-01 -3.657890e-02
# 105     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 110    -3.673013e-02 -3.673013e-02 -3.673013e-02 -3.673013e-02  1.474209e-01
# 115     1.450668e-01 -3.614751e-02 -3.614751e-02 -3.614751e-02 -3.614751e-02
# 120     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 125     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 130    -1.441004e-01  3.590827e-02  3.590827e-02  3.590827e-02  3.590827e-02
# 135    -1.387779e-17 -1.387779e-17 -1.387779e-17 -1.387779e-17 -1.387779e-17
# Fin

# %% [markdown]
# ## Identify Phase-locked Target Frames in a Series of Reference Heartbeats
#
# ### Using Standard Sum of Squared Differences
#
# The next cell takes a series of real reference heartbeatsand runs the original adaptive optical gating algorithm based on sum of squared differences to identify a phase-locked target frame throughout time.
#
# Please see the Python module documentation for all details.

# %%
# Set-Up arrays for keeping history
sequence_history = None
period_history = None
drift_history = None
shift_history = None

for ref in results.index:
    # Load reference period images
    this_sequence = io.imread(os.path.join(root,'reference{0:04d}.tif'.format(ref)))
    this_period = results.loc[ref,'Period']  # as stored in periods.csv
    this_drift = (results.loc[ref,'Drift_X'], results.loc[ref,'Drift_Y'])  # as stored in periods.csv
    
    # Process new reference period using the 'cross correlation' ("cc") algorithm, note this is sum of squared differences
    # We will use the default Fast Fourier Transform form of this algorithm (as it's the fastest); see documentation for other methods.
    # By default this algorithm will resample a period to be 80 frames long
    (sequence_history,
     period_history,
     drift_history,
     shift_history,
     global_solution,
     target) = oga.process_sequence(this_sequence,
                                    this_period,
                                    this_drift,
                                    sequence_history=sequence_history,
                                    period_history=period_history,
                                    drift_history=drift_history,
                                    shift_history=shift_history,
                                    max_offset=3,
                                    ref_seq_id=0,
                                    ref_seq_phase=initialTarget,
                                    algorithm="cc")
    
    # Convert target to radians
    target_radians = 2 * np.pi * target / this_period
    
    # Store results
    results.loc[ref,'Adaptive'] = target_radians

print('Fin')
# Out:
# Processing new sequence (Period: 34.282163; Drift: (0, 0); 0 past sequences).
# Creating new histories.
# New target (base this_period): 13.597565048856001
# Processing new sequence (Period: 34.616525; Drift: (0, 0); 1 past sequences).
# New target (base this_period): 1.072589132790473
# Processing new sequence (Period: 34.261581; Drift: (0, 0); 2 past sequences).
# New target (base this_period): 18.538741206297807
# Processing new sequence (Period: 34.051320000000004; Drift: (0, 0); 3 past sequences).
# New target (base this_period): 31.50152722457971
# Processing new sequence (Period: 34.11974; Drift: (0, 0); 4 past sequences).
# New target (base this_period): 18.00099916785718
# Processing new sequence (Period: 34.672674; Drift: (0, 0); 5 past sequences).
# New target (base this_period): 17.17507614036272
# Processing new sequence (Period: 34.720043; Drift: (0, 0); 6 past sequences).
# New target (base this_period): 0.7924848014274349
# Processing new sequence (Period: 35.019436999999996; Drift: (0, 0); 7 past sequences).
# New target (base this_period): 8.181752105811015
# Processing new sequence (Period: 34.904905; Drift: (0, 0); 8 past sequences).
# New target (base this_period): 11.422068124522117
# Processing new sequence (Period: 34.565785; Drift: (0, 0); 9 past sequences).
# New target (base this_period): 1.2866242570401536
# Processing new sequence (Period: 9.00717; Drift: (0, 0); 10 past sequences).
# New target (base this_period): 7.596366850304247
# Processing new sequence (Period: 34.542719; Drift: (0, 0); 11 past sequences).
# New target (base this_period): 1.4842922231589823
# Processing new sequence (Period: 34.91879; Drift: (0, 0); 12 past sequences).
# New target (base this_period): 15.71651855764909
# Processing new sequence (Period: 35.153265999999995; Drift: (0, 0); 13 past sequences).
# New target (base this_period): 9.952512995676104
# Processing new sequence (Period: 34.571787; Drift: (0, 0); 14 past sequences).
# New target (base this_period): 1.6669904666327515
# Processing new sequence (Period: 34.562445000000004; Drift: (0, 0); 15 past sequences).
# New target (base this_period): 27.767016727659655
# Processing new sequence (Period: 34.575828; Drift: (0, 0); 16 past sequences).
# New target (base this_period): 26.21246196525393
# Processing new sequence (Period: 34.027988; Drift: (0, 0); 17 past sequences).
# New target (base this_period): 26.72818673938262
# Processing new sequence (Period: 34.732488000000004; Drift: (0, 0); 18 past sequences).
# New target (base this_period): 1.2251966401749252
# Processing new sequence (Period: 34.478854; Drift: (0, 0); 19 past sequences).
# New target (base this_period): 8.846658309030822
# Processing new sequence (Period: 34.311661; Drift: (0, 0); 20 past sequences).
# New target (base this_period): 29.969471332112658
# Processing new sequence (Period: 34.741252; Drift: (0, 0); 21 past sequences).
# New target (base this_period): 7.531577129776996
# Processing new sequence (Period: 35.448847; Drift: (0, 0); 22 past sequences).
# New target (base this_period): 9.345062965195352
# Processing new sequence (Period: 34.066429; Drift: (0, 0); 23 past sequences).
# New target (base this_period): 26.869000803399008
# Processing new sequence (Period: 34.595999; Drift: (0, 0); 24 past sequences).
# New target (base this_period): 20.011397527676387
# Processing new sequence (Period: 34.536362; Drift: (0, 0); 25 past sequences).
# New target (base this_period): 1.7280636550543345
# Processing new sequence (Period: 33.826905; Drift: (0, 0); 26 past sequences).
# New target (base this_period): 24.818426121132465
# Processing new sequence (Period: 34.174556; Drift: (0, 0); 27 past sequences).
# New target (base this_period): 10.454471465843152
# Processing new sequence (Period: 33.635673; Drift: (0, 0); 28 past sequences).
# New target (base this_period): 15.933645143009619
# Processing new sequence (Period: 33.347438000000004; Drift: (0, 0); 29 past sequences).
# New target (base this_period): 4.770623069935591
# Processing new sequence (Period: 34.052276; Drift: (0, 0); 30 past sequences).
# New target (base this_period): 11.377024253861071
# Processing new sequence (Period: 34.388172999999995; Drift: (0, 0); 31 past sequences).
# New target (base this_period): 22.238257342221395
# Processing new sequence (Period: 34.468261; Drift: (0, 0); 32 past sequences).
# New target (base this_period): 18.644639944977282
# Processing new sequence (Period: 34.754616999999996; Drift: (0, 0); 33 past sequences).
# New target (base this_period): 1.9857595751191848
# Processing new sequence (Period: 34.062799; Drift: (0, 0); 34 past sequences).
# New target (base this_period): 0.49410298525851815
# Processing new sequence (Period: 34.272296000000004; Drift: (0, 0); 35 past sequences).
# New target (base this_period): 18.615769099410258
# Processing new sequence (Period: 34.815356; Drift: (0, 0); 36 past sequences).
# New target (base this_period): 2.659369029306995
# Processing new sequence (Period: 35.379985; Drift: (0, 0); 37 past sequences).
# New target (base this_period): 10.017233789442404
# Processing new sequence (Period: 34.998353; Drift: (0, 0); 38 past sequences).
# New target (base this_period): 3.6572818724898193
# Processing new sequence (Period: 34.884526; Drift: (0, 0); 39 past sequences).
# New target (base this_period): 34.73047533835133
# Processing new sequence (Period: 34.042735; Drift: (0, 0); 40 past sequences).
# New target (base this_period): 15.973046701513661
# Processing new sequence (Period: 35.020374; Drift: (0, 0); 41 past sequences).
# New target (base this_period): 34.881613914687044
# Processing new sequence (Period: 34.645399; Drift: (0, 0); 42 past sequences).
# New target (base this_period): 6.773360272947251
# Processing new sequence (Period: 34.790841; Drift: (0, 0); 43 past sequences).
# New target (base this_period): 0.05087711089465129
# Processing new sequence (Period: 35.052839; Drift: (0, 0); 44 past sequences).
# New target (base this_period): 33.98126338639361
# Processing new sequence (Period: 34.632574; Drift: (0, 0); 45 past sequences).
# New target (base this_period): 24.657629342587217
# Processing new sequence (Period: 34.528438; Drift: (0, 0); 46 past sequences).
# New target (base this_period): 30.83038478078518
# Processing new sequence (Period: 34.854602; Drift: (0, 0); 47 past sequences).
# New target (base this_period): 1.5647522285728344
# Processing new sequence (Period: 34.523691; Drift: (0, 0); 48 past sequences).
# New target (base this_period): 0.48183355349880214
# Processing new sequence (Period: 34.765898; Drift: (0, 0); 49 past sequences).
# New target (base this_period): 19.263944235955684
# Processing new sequence (Period: 34.883989; Drift: (0, 0); 50 past sequences).
# New target (base this_period): 25.87292737083239
# Processing new sequence (Period: 34.460029999999996; Drift: (0, 0); 51 past sequences).
# New target (base this_period): 21.499634022797565
# Processing new sequence (Period: 34.569907; Drift: (0, 0); 52 past sequences).
# New target (base this_period): 22.3799748474408
# Processing new sequence (Period: 33.89808; Drift: (0, 0); 53 past sequences).
# New target (base this_period): 13.93822724843688
# Processing new sequence (Period: 33.841171; Drift: (0, 0); 54 past sequences).
# New target (base this_period): 0.4946091576847606
# Processing new sequence (Period: 34.040822999999996; Drift: (0, 0); 55 past sequences).
# New target (base this_period): 5.831414899589389
# Processing new sequence (Period: 34.442516; Drift: (0, 0); 56 past sequences).
# New target (base this_period): 8.127241168910732
# Processing new sequence (Period: 34.175714; Drift: (0, 0); 57 past sequences).
# New target (base this_period): 8.869869239403693
# Processing new sequence (Period: 33.094206; Drift: (0, 0); 58 past sequences).
# New target (base this_period): 31.707739765830343
# Processing new sequence (Period: 32.741163; Drift: (0, 0); 59 past sequences).
# New target (base this_period): 26.820396636049786
# Processing new sequence (Period: 33.502881; Drift: (0, 0); 60 past sequences).
# New target (base this_period): 26.370955002808575
# Processing new sequence (Period: 33.891369; Drift: (0, 0); 61 past sequences).
# New target (base this_period): 7.6926568465530565
# Processing new sequence (Period: 33.423840000000006; Drift: (0, 0); 62 past sequences).
# New target (base this_period): 24.620294536178985
# Processing new sequence (Period: 33.349845; Drift: (0, 0); 63 past sequences).
# New target (base this_period): 8.933510170673781
# Processing new sequence (Period: 33.309172; Drift: (0, 0); 64 past sequences).
# New target (base this_period): 33.17376572687435
# Processing new sequence (Period: 33.44715; Drift: (0, 0); 65 past sequences).
# New target (base this_period): 19.291216578190777
# Processing new sequence (Period: 33.167501; Drift: (0, 0); 66 past sequences).
# New target (base this_period): 8.632069770257424
# Processing new sequence (Period: 33.218191; Drift: (0, 0); 67 past sequences).
# New target (base this_period): 18.205800841649065
# Processing new sequence (Period: 32.634065; Drift: (0, 0); 68 past sequences).
# New target (base this_period): 6.91160630420824
# Processing new sequence (Period: 32.502022; Drift: (0, 0); 69 past sequences).
# New target (base this_period): 6.7774789902741
# Processing new sequence (Period: 32.906454; Drift: (0, 0); 70 past sequences).
# New target (base this_period): 8.705127078140379
# Processing new sequence (Period: 32.675703999999996; Drift: (0, 0); 71 past sequences).
# New target (base this_period): 8.678581448212604
# Processing new sequence (Period: 32.474708; Drift: (0, 0); 72 past sequences).
# New target (base this_period): 7.332157544849079
# Processing new sequence (Period: 32.481190000000005; Drift: (0, 0); 73 past sequences).
# New target (base this_period): 32.251253386281164
# Processing new sequence (Period: 32.722414; Drift: (0, 0); 74 past sequences).
# New target (base this_period): 9.321258220403893
# Processing new sequence (Period: 32.5602; Drift: (0, 0); 75 past sequences).
# New target (base this_period): 31.818997057539445
# Processing new sequence (Period: 32.396485; Drift: (0, 0); 76 past sequences).
# New target (base this_period): 22.931338542914666
# Processing new sequence (Period: 32.271814; Drift: (0, 0); 77 past sequences).
# New target (base this_period): 31.252643794522392
# Processing new sequence (Period: 32.766614000000004; Drift: (0, 0); 78 past sequences).
# New target (base this_period): 16.834814985486656
# Fin

# %% [markdown]
# ### Using Cascading Needleman-Wunsch Algorithm
#
# The next cell takes a series of real reference heartbeatsand runs the new adaptive optical gating algorithm based on the cascading Needleman-Wunsch algorithm to identify a phase-locked target frame throughout time.
#
# Please see the Python module documentation for all details.

# %%
from optical_gating_alignment import helper as hlp

# Set-Up arrays for keeping history
sequence_history = None
period_history = None
drift_history = None
shift_history = None
global_solution = None

for ref in results.index:
    # Load reference period images
    this_sequence = hlp.interpolate_image_sequence(io.imread(os.path.join(root,'reference{0:04d}.tif'.format(ref)))[2:-2], results.loc[ref,'Period'], interpolation_factor=80/results.loc[ref,'Period'])[:80]
#     this_sequence = io.imread(os.path.join(root,'reference{0:04d}.tif'.format(ref)))[2:-2]
    this_period = 80#results.loc[ref,'Period']  # as stored in periods.csv
    this_drift = (results.loc[ref,'Drift_X'], results.loc[ref,'Drift_Y'])  # as stored in periods.csv
    
    # Process new reference period using the 'cross correlation' ("cc") algorithm, note this is sum of squared differences
    # We will specifically use the default Fast Fourier Transform form of this algorithm (as it's the fastest); see documentation for other methods.
    # By default this algorithm will resample a period to be 80 frames long
    (sequence_history,
     period_history,
     drift_history,
     shift_history,
     global_solution,
     target) = oga.process_sequence(this_sequence,
                                    this_period,
                                    this_drift,
                                    sequence_history=sequence_history,
                                    period_history=period_history,
                                    drift_history=drift_history,
                                    shift_history=shift_history,
                                    global_solution=global_solution,
                                    max_offset=3,
                                    ref_seq_id=0,
                                    ref_seq_phase=initialTarget*80/results['Period'].values[0],
                                    algorithm="cnw")
    
    # Convert target to radians
    target_radians = 2 * np.pi * target / this_period
    
    # Store results
    results.loc[ref,'Dynamic'] = target_radians

print('Fin')
# Out:
# Processing new sequence (Period: 80; Drift: (0, 0); 0 past sequences).
# Creating new histories.
# New target (base this_period): 31.73093844482567
# Processing new sequence (Period: 80; Drift: (0, 0); 1 past sequences).
# New target (base this_period): 2.7309384448256395
# Processing new sequence (Period: 80; Drift: (0, 0); 2 past sequences).
# New target (base this_period): 43.73093844482568
# Processing new sequence (Period: 80; Drift: (0, 0); 3 past sequences).
# New target (base this_period): 74.26886505542473
# Processing new sequence (Period: 80; Drift: (0, 0); 4 past sequences).
# New target (base this_period): 42.41249167491358
# Processing new sequence (Period: 80; Drift: (0, 0); 5 past sequences).
# New target (base this_period): 39.73778649794565
# Processing new sequence (Period: 80; Drift: (0, 0); 6 past sequences).
# New target (base this_period): 2.1670074432391857
# Processing new sequence (Period: 80; Drift: (0, 0); 7 past sequences).
# New target (base this_period): 19.160078035786626
# Processing new sequence (Period: 80; Drift: (0, 0); 8 past sequences).
# New target (base this_period): 26.41477561089164
# Processing new sequence (Period: 80; Drift: (0, 0); 9 past sequences).
# New target (base this_period): 3.2135973434269545
# Processing new sequence (Period: 80; Drift: (0, 0); 10 past sequences).
# New target (base this_period): 75.93243100086454
# Processing new sequence (Period: 80; Drift: (0, 0); 11 past sequences).
# New target (base this_period): 2.89288535089554
# Processing new sequence (Period: 80; Drift: (0, 0); 12 past sequences).
# Major discrepancy between approx expected value 42.99999999999983 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# Major discrepancy between approx expected value 39.77206042962831 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# Major discrepancy between approx expected value 39.77206042962831 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# Major discrepancy between approx expected value 39.77206042962831 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# Major discrepancy between approx expected value 39.77206042962831 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 34.67596290487859
# Processing new sequence (Period: 80; Drift: (0, 0); 13 past sequences).
# Major discrepancy between approx expected value 43.000000000000114 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 30.461157776348273
# Processing new sequence (Period: 80; Drift: (0, 0); 14 past sequences).
# Major discrepancy between approx expected value 42.99999999999983 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 9.4346435989047
# Processing new sequence (Period: 80; Drift: (0, 0); 15 past sequences).
# Major discrepancy between approx expected value 43.0 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 70.98661023420163
# Processing new sequence (Period: 80; Drift: (0, 0); 16 past sequences).
# Major discrepancy between approx expected value 43.0 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 67.1128810866312
# Processing new sequence (Period: 80; Drift: (0, 0); 17 past sequences).
# Major discrepancy between approx expected value 42.99999999999983 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 68.91130591181309
# Processing new sequence (Period: 80; Drift: (0, 0); 18 past sequences).
# Major discrepancy between approx expected value 43.00000000000023 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 9.212319455981287
# Processing new sequence (Period: 80; Drift: (0, 0); 19 past sequences).
# Major discrepancy between approx expected value 43.000000000000284 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 26.619143117041745
# Processing new sequence (Period: 80; Drift: (0, 0); 20 past sequences).
# Major discrepancy between approx expected value 42.999999999999545 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 75.92560945255275
# Processing new sequence (Period: 80; Drift: (0, 0); 21 past sequences).
# Major discrepancy between approx expected value 43.0 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 23.557774086827294
# Processing new sequence (Period: 80; Drift: (0, 0); 22 past sequences).
# Major discrepancy between approx expected value 43.000000000000114 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 27.35354042442077
# Processing new sequence (Period: 80; Drift: (0, 0); 23 past sequences).
# Major discrepancy between approx expected value 43.00000000000051 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 69.25168621213061
# Processing new sequence (Period: 80; Drift: (0, 0); 24 past sequences).
# Major discrepancy between approx expected value 43.00000000000034 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 52.346588669161974
# Processing new sequence (Period: 80; Drift: (0, 0); 25 past sequences).
# Major discrepancy between approx expected value 42.99999999999994 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 10.317865739180434
# Processing new sequence (Period: 80; Drift: (0, 0); 26 past sequences).
# Major discrepancy between approx expected value 43.00000000000006 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 64.98298040193163
# Processing new sequence (Period: 80; Drift: (0, 0); 27 past sequences).
# Major discrepancy between approx expected value 43.00000000000017 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 30.879969426961907
# Processing new sequence (Period: 80; Drift: (0, 0); 28 past sequences).
# Major discrepancy between approx expected value 43.00000000000017 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 44.32487891164419
# Processing new sequence (Period: 80; Drift: (0, 0); 29 past sequences).
# Major discrepancy between approx expected value 43.00000000000006 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 17.690467187956983
# Processing new sequence (Period: 80; Drift: (0, 0); 30 past sequences).
# Major discrepancy between approx expected value 43.000000000000284 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 33.304554613432856
# Processing new sequence (Period: 80; Drift: (0, 0); 31 past sequences).
# Major discrepancy between approx expected value 43.00000000000023 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 58.201752058685315
# Processing new sequence (Period: 80; Drift: (0, 0); 32 past sequences).
# Major discrepancy between approx expected value 43.000000000000284 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 49.80030109410518
# Processing new sequence (Period: 80; Drift: (0, 0); 33 past sequences).
# Major discrepancy between approx expected value 43.000000000000284 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 11.097489922500472
# Processing new sequence (Period: 80; Drift: (0, 0); 34 past sequences).
# Major discrepancy between approx expected value 43.000000000000284 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 7.673412269513392
# Processing new sequence (Period: 80; Drift: (0, 0); 35 past sequences).
# Major discrepancy between approx expected value 43.00000000000006 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 49.824534904610346
# Processing new sequence (Period: 80; Drift: (0, 0); 36 past sequences).
# Major discrepancy between approx expected value 43.00000000000006 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 12.833550643224953
# Processing new sequence (Period: 80; Drift: (0, 0); 37 past sequences).
# Major discrepancy between approx expected value 43.00000000000017 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 29.470018397043305
# Processing new sequence (Period: 80; Drift: (0, 0); 38 past sequences).
# Major discrepancy between approx expected value 43.000000000000455 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 15.037991457428916
# Processing new sequence (Period: 80; Drift: (0, 0); 39 past sequences).
# Major discrepancy between approx expected value 43.00000000000023 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 6.054281521044686
# Processing new sequence (Period: 80; Drift: (0, 0); 40 past sequences).
# Major discrepancy between approx expected value 43.000000000000114 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 44.13722170214146
# Processing new sequence (Period: 80; Drift: (0, 0); 41 past sequences).
# Major discrepancy between approx expected value 43.000000000000114 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 6.089765039122312
# Processing new sequence (Period: 80; Drift: (0, 0); 42 past sequences).
# Major discrepancy between approx expected value 43.000000000000455 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 22.09795746053487
# Processing new sequence (Period: 80; Drift: (0, 0); 43 past sequences).
# Major discrepancy between approx expected value 42.99999999999983 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 6.453195342827257
# Processing new sequence (Period: 80; Drift: (0, 0); 44 past sequences).
# Major discrepancy between approx expected value 43.00000000000017 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 3.9572260028921846
# Processing new sequence (Period: 80; Drift: (0, 0); 45 past sequences).
# Major discrepancy between approx expected value 43.00000000000051 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 63.55737474012108
# Processing new sequence (Period: 80; Drift: (0, 0); 46 past sequences).
# Major discrepancy between approx expected value 43.00000000000057 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 77.65781818779419
# Processing new sequence (Period: 80; Drift: (0, 0); 47 past sequences).
# Major discrepancy between approx expected value 43.000000000000284 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 10.024199894891808
# Processing new sequence (Period: 80; Drift: (0, 0); 48 past sequences).
# Major discrepancy between approx expected value 43.00000000000057 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 7.395609653675365
# Processing new sequence (Period: 80; Drift: (0, 0); 49 past sequences).
# Major discrepancy between approx expected value 43.00000000000034 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 50.70495696198168
# Processing new sequence (Period: 80; Drift: (0, 0); 50 past sequences).
# Major discrepancy between approx expected value 43.000000000000284 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 65.33770126899117
# Processing new sequence (Period: 80; Drift: (0, 0); 51 past sequences).
# Major discrepancy between approx expected value 43.00000000000051 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 56.12269507899646
# Processing new sequence (Period: 80; Drift: (0, 0); 52 past sequences).
# Major discrepancy between approx expected value 43.000000000000284 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 58.027612309103006
# Processing new sequence (Period: 80; Drift: (0, 0); 53 past sequences).
# Major discrepancy between approx expected value 43.00000000000034 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 38.7719373365062
# Processing new sequence (Period: 80; Drift: (0, 0); 54 past sequences).
# Major discrepancy between approx expected value 43.000000000000796 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 6.918892746729398
# Processing new sequence (Period: 80; Drift: (0, 0); 55 past sequences).
# Major discrepancy between approx expected value 43.00000000000051 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 19.893911685901912
# Processing new sequence (Period: 80; Drift: (0, 0); 56 past sequences).
# Major discrepancy between approx expected value 43.00000000000051 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 24.876325079617345
# Processing new sequence (Period: 80; Drift: (0, 0); 57 past sequences).
# Major discrepancy between approx expected value 43.00000000000068 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 26.89081602353599
# Processing new sequence (Period: 80; Drift: (0, 0); 58 past sequences).
# Major discrepancy between approx expected value 43.000000000000284 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 2.8868572958199366
# Processing new sequence (Period: 80; Drift: (0, 0); 59 past sequences).
# Major discrepancy between approx expected value 43.00000000000193 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 71.55168588421247
# Processing new sequence (Period: 80; Drift: (0, 0); 60 past sequences).
# Major discrepancy between approx expected value 43.00000000000142 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 69.4692447614334
# Processing new sequence (Period: 80; Drift: (0, 0); 61 past sequences).
# Major discrepancy between approx expected value 43.000000000001194 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 24.312267412400615
# Processing new sequence (Period: 80; Drift: (0, 0); 62 past sequences).
# Major discrepancy between approx expected value 43.00000000000017 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 65.41064111799051
# Processing new sequence (Period: 80; Drift: (0, 0); 63 past sequences).
# Major discrepancy between approx expected value 43.000000000000455 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 27.390342435379807
# Processing new sequence (Period: 80; Drift: (0, 0); 64 past sequences).
# Major discrepancy between approx expected value 43.000000000000625 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 6.068945644525684
# Processing new sequence (Period: 80; Drift: (0, 0); 65 past sequences).
# Major discrepancy between approx expected value 43.000000000000284 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 52.69249254800479
# Processing new sequence (Period: 80; Drift: (0, 0); 66 past sequences).
# Major discrepancy between approx expected value 43.000000000000114 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 27.511747065078453
# Processing new sequence (Period: 80; Drift: (0, 0); 67 past sequences).
# Major discrepancy between approx expected value 43.00000000000017 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 50.47449052830416
# Processing new sequence (Period: 80; Drift: (0, 0); 68 past sequences).
# Major discrepancy between approx expected value 43.00000000000023 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 23.182090083302683
# Processing new sequence (Period: 80; Drift: (0, 0); 69 past sequences).
# Major discrepancy between approx expected value 43.00000000000034 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 23.33833385880689
# Processing new sequence (Period: 80; Drift: (0, 0); 70 past sequences).
# Major discrepancy between approx expected value 43.0000000000004 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 27.315905404492696
# Processing new sequence (Period: 80; Drift: (0, 0); 71 past sequences).
# Major discrepancy between approx expected value 43.000000000000284 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 27.61053721637427
# Processing new sequence (Period: 80; Drift: (0, 0); 72 past sequences).
# Major discrepancy between approx expected value 43.000000000000455 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 24.39805224061547
# Processing new sequence (Period: 80; Drift: (0, 0); 73 past sequences).
# Major discrepancy between approx expected value 43.00000000000023 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 5.519255379018432
# Processing new sequence (Period: 80; Drift: (0, 0); 74 past sequences).
# Major discrepancy between approx expected value 43.00000000000023 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 29.510524257976613
# Processing new sequence (Period: 80; Drift: (0, 0); 75 past sequences).
# Major discrepancy between approx expected value 43.000000000000284 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 4.492267551514942
# Processing new sequence (Period: 80; Drift: (0, 0); 76 past sequences).
# Major discrepancy between approx expected value 43.000000000000284 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 63.129580751769026
# Processing new sequence (Period: 80; Drift: (0, 0); 77 past sequences).
# Major discrepancy between approx expected value 43.00000000000017 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 4.027412936631208
# Processing new sequence (Period: 80; Drift: (0, 0); 78 past sequences).
# Major discrepancy between approx expected value 43.000000000000284 and actual value 64.0 for (10, 12) (distance 2; score 8.198705528846153)
# New target (base this_period): 47.957393998609405
# Fin

# %% [markdown]
# ### Using cNW and interpolation
#
# The next cell takes a series of real reference heartbeats, captured once every three adaptive optical gating stacks, and runs the adaptive optical gating algorithms used to identify a phase-locked target frame across 18 hours of time-lapse imaging.
#
# The key bit of code here is the calling of `cnw.processNewReferenceSequence()`, which is used in the live system.
#
# For ease the documentation from the Python file explaining the inputs and outputs is copied below:
# ```
# Inputs:
# * rawRefFrames: a PxMxN numpy array representing the new reference frames (or a list of numpy arrays representing the new reference frames)
# * thisPeriod: the period for rawRefFrames (caller must determine this)
# * thisDrift: the drift for rawRefFrames (caller must determine this)
#  * if None no drift correction is used
# * resampledSequences: a list of resampled, previous reference frames
# * periodHistory: a list of the previous periods for resampledSequences
# * driftHistory: a list of the previous drifts for resampledSequences
#  * if no drift correction is used, this is a dummy variable
# * shifts: a list of shifts previously calculated for resampledSequences
# * knownPhaseIndex: the index of resampledSequences for which knownPhase applies
# * knownPhase: the phase (index) we are trying to match in knownPhaseIndex
# * numSamplesPerPeriod: the number of samples to use in resampling
# * maxOffsetToConsider: how far apart historically to make comparisons
#  * should be used to prevent comparing sequences that are far apart and have little similarity
#
# Outputs:
# * resampledSequences: updated list of resampled reference frames
# * periodHistory: updated list of the periods for resampledSequences
# * driftHistory: updated list of the drifts for resampledSequences
#  * if no drift correction is used, this is a dummy variable
# * shifts: updated list of shifts calculated for resampledSequences
# * globalShiftSolution[-1]: roll factor for latest reference frames
# * residuals: residuals on least squares solution'''
# ```

# %%
# %%time

# # Set-Up arrays for keeping history
# sequence_history = None
# period_history = None
# drift_history = None
# shift_history = None
# global_solution = None

# for ref in results.index:
#     # Load reference period images
#     this_sequence = hlp.interpolate_image_sequence(io.imread(os.path.join(root,'reference{0:04d}.tif'.format(ref)))[2:-2], results.loc[ref,'Period'], interpolation_factor=320/results.loc[ref,'Period'])[:320]
# #     this_sequence = io.imread(os.path.join(root,'reference{0:04d}.tif'.format(ref)))[2:-2]
#     this_period = 320#results.loc[ref,'Period']  # as stored in periods.csv
#     this_drift = (results.loc[ref,'Drift_X'], results.loc[ref,'Drift_Y'])  # as stored in periods.csv
    
#     # Process new reference period using the 'cross correlation' ("cc") algorithm, note this is sum of squared differences
#     # We will specifically use the default Fast Fourier Transform form of this algorithm (as it's the fastest); see documentation for other methods.
#     # By default this algorithm will resample a period to be 80 frames long
#     %time (sequence_history,\
#      period_history,\
#      drift_history,\
#      shift_history,\
#      global_solution,\
#      target) = oga.process_sequence(this_sequence,\
#                                     this_period,\
#                                     this_drift,\
#                                     sequence_history=sequence_history,\
#                                     period_history=period_history,\
#                                     drift_history=drift_history,\
#                                     shift_history=shift_history,\
#                                     global_solution=global_solution,\
#                                     max_offset=3,\
#                                     ref_seq_id=0,\
#                                     ref_seq_phase=initialTarget*320/results['Period'].values[0],\
#                                     algorithm="cnw")
    
#     # Convert target to radians
#     target_radians = 2 * np.pi * target / this_period
    
#     # Store results
#     results.loc[ref,'SuperDynamic'] = target_radians

# print('Fin')
# Out:
# Processing new sequence (Period: 320; Drift: (0, 0); 0 past sequences).
# Creating new histories.
# New target (base this_period): 126.92375377930269
# CPU times: user 25.7 ms, sys: 24.7 ms, total: 50.4 ms
# Wall time: 7.85 ms
# Processing new sequence (Period: 320; Drift: (0, 0); 1 past sequences).
# New target (base this_period): 9.923753779302842
# CPU times: user 3.16 s, sys: 42.1 ms, total: 3.2 s
# Wall time: 3.21 s
# Processing new sequence (Period: 320; Drift: (0, 0); 2 past sequences).
# New target (base this_period): 173.92375377930279
# CPU times: user 6.26 s, sys: 126 ms, total: 6.38 s
# Wall time: 6.39 s
# Processing new sequence (Period: 320; Drift: (0, 0); 3 past sequences).
# New target (base this_period): 296.6677503065098
# CPU times: user 9.46 s, sys: 177 ms, total: 9.64 s
# Wall time: 9.65 s
# Processing new sequence (Period: 320; Drift: (0, 0); 4 past sequences).
# New target (base this_period): 168.87593472370338
# CPU times: user 9.1 s, sys: 158 ms, total: 9.26 s
# Wall time: 9.27 s
# Processing new sequence (Period: 320; Drift: (0, 0); 5 past sequences).
# New target (base this_period): 159.916872793214
# CPU times: user 9.49 s, sys: 162 ms, total: 9.65 s
# Wall time: 9.68 s
# Processing new sequence (Period: 320; Drift: (0, 0); 6 past sequences).
# New target (base this_period): 8.26117679366871
# CPU times: user 9.23 s, sys: 163 ms, total: 9.39 s
# Wall time: 9.41 s
# Processing new sequence (Period: 320; Drift: (0, 0); 7 past sequences).
# New target (base this_period): 76.16653465587592
# CPU times: user 9.27 s, sys: 164 ms, total: 9.43 s
# Wall time: 9.46 s
# Processing new sequence (Period: 320; Drift: (0, 0); 8 past sequences).
# New target (base this_period): 105.4887993516702
# CPU times: user 9.27 s, sys: 161 ms, total: 9.43 s
# Wall time: 9.45 s
# Processing new sequence (Period: 320; Drift: (0, 0); 9 past sequences).
# New target (base this_period): 12.900382903587342
# CPU times: user 9.09 s, sys: 165 ms, total: 9.26 s
# Wall time: 9.27 s
# Processing new sequence (Period: 320; Drift: (0, 0); 10 past sequences).
# New target (base this_period): 303.0689154739455
# CPU times: user 9.11 s, sys: 149 ms, total: 9.26 s
# Wall time: 9.27 s
# Processing new sequence (Period: 320; Drift: (0, 0); 11 past sequences).
# New target (base this_period): 10.805043486111344
# CPU times: user 8.88 s, sys: 156 ms, total: 9.04 s
# Wall time: 9.05 s
# Processing new sequence (Period: 320; Drift: (0, 0); 12 past sequences).
# Major discrepancy between approx expected value 168.9999999999991 and actual value 256.0 for (10, 12) (distance 2; score 8.197332832532052)
# Major discrepancy between approx expected value 159.00935484925685 and actual value 256.0 for (10, 12) (distance 2; score 8.197332832532052)
# Major discrepancy between approx expected value 159.00935484925685 and actual value 256.0 for (10, 12) (distance 2; score 8.197332832532052)
# Major discrepancy between approx expected value 159.00935484925685 and actual value 256.0 for (10, 12) (distance 2; score 8.197332832532052)
# Major discrepancy between approx expected value 159.00935484925685 and actual value 256.0 for (10, 12) (distance 2; score 8.197332832532052)
# New target (base this_period): 138.75418002970082
# CPU times: user 9 s, sys: 163 ms, total: 9.16 s
# Wall time: 9.17 s
# Processing new sequence (Period: 320; Drift: (0, 0); 13 past sequences).
# Major discrepancy between approx expected value 168.99999999999977 and actual value 256.0 for (10, 12) (distance 2; score 8.197332832532052)
# New target (base this_period): 121.71397832566845
# CPU times: user 8.96 s, sys: 166 ms, total: 9.12 s
# Wall time: 9.13 s
# Processing new sequence (Period: 320; Drift: (0, 0); 14 past sequences).
# Major discrepancy between approx expected value 168.99999999999886 and actual value 256.0 for (10, 12) (distance 2; score 8.197332832532052)
# New target (base this_period): 38.08015268104464
# CPU times: user 9.03 s, sys: 171 ms, total: 9.2 s
# Wall time: 9.21 s
# Processing new sequence (Period: 320; Drift: (0, 0); 15 past sequences).
# Major discrepancy between approx expected value 168.99999999999932 and actual value 256.0 for (10, 12) (distance 2; score 8.197332832532052)
# New target (base this_period): 283.1847708025589
# CPU times: user 9.12 s, sys: 154 ms, total: 9.27 s
# Wall time: 9.29 s
# Processing new sequence (Period: 320; Drift: (0, 0); 16 past sequences).
# Major discrepancy between approx expected value 168.99999999999886 and actual value 256.0 for (10, 12) (distance 2; score 8.197332832532052)
# New target (base this_period): 267.2686162269101
# CPU times: user 9.18 s, sys: 187 ms, total: 9.37 s
# Wall time: 9.39 s
# Processing new sequence (Period: 320; Drift: (0, 0); 17 past sequences).
# Major discrepancy between approx expected value 168.99999999999932 and actual value 256.0 for (10, 12) (distance 2; score 8.197332832532052)
# New target (base this_period): 275.7945484802631
# CPU times: user 9.25 s, sys: 191 ms, total: 9.44 s
# Wall time: 9.46 s
# Processing new sequence (Period: 320; Drift: (0, 0); 18 past sequences).
# Major discrepancy between approx expected value 168.99999999999932 and actual value 256.0 for (10, 12) (distance 2; score 8.197332832532052)
# New target (base this_period): 36.39880866498197
# CPU times: user 9.22 s, sys: 194 ms, total: 9.41 s
# Wall time: 9.43 s
# Processing new sequence (Period: 320; Drift: (0, 0); 19 past sequences).
# Major discrepancy between approx expected value 168.99999999999955 and actual value 256.0 for (10, 12) (distance 2; score 8.197332832532052)
# New target (base this_period): 107.21649307211419
# CPU times: user 9.2 s, sys: 178 ms, total: 9.38 s
# Wall time: 9.4 s
# Processing new sequence (Period: 320; Drift: (0, 0); 20 past sequences).
# Major discrepancy between approx expected value 169.00000000000023 and actual value 256.0 for (10, 12) (distance 2; score 8.197332832532052)
# New target (base this_period): 303.8267554213039
# CPU times: user 9.3 s, sys: 184 ms, total: 9.49 s
# Wall time: 9.5 s
# Processing new sequence (Period: 320; Drift: (0, 0); 21 past sequences).
# Major discrepancy between approx expected value 168.99999999999977 and actual value 256.0 for (10, 12) (distance 2; score 8.197332832532052)
# New target (base this_period): 94.08889308317339
# CPU times: user 9.41 s, sys: 194 ms, total: 9.6 s
# Wall time: 9.63 s
# Processing new sequence (Period: 320; Drift: (0, 0); 22 past sequences).
# Major discrepancy between approx expected value 169.0000000000009 and actual value 256.0 for (10, 12) (distance 2; score 8.197332832532052)
# New target (base this_period): 108.92699288277618
# CPU times: user 9.43 s, sys: 194 ms, total: 9.63 s
# Wall time: 9.65 s
# Processing new sequence (Period: 320; Drift: (0, 0); 23 past sequences).
# Major discrepancy between approx expected value 168.99999999999977 and actual value 256.0 for (10, 12) (distance 2; score 8.197332832532052)
# New target (base this_period): 276.5496295747753
# CPU times: user 9.58 s, sys: 190 ms, total: 9.77 s
# Wall time: 9.8 s
# Processing new sequence (Period: 320; Drift: (0, 0); 24 past sequences).
# Major discrepancy between approx expected value 169.00000000000136 and actual value 256.0 for (10, 12) (distance 2; score 8.197332832532052)
# New target (base this_period): 209.8796319308476
# CPU times: user 9.47 s, sys: 188 ms, total: 9.66 s
# Wall time: 9.89 s
# Processing new sequence (Period: 320; Drift: (0, 0); 25 past sequences).
# Major discrepancy between approx expected value 168.99999999999977 and actual value 256.0 for (10, 12) (distance 2; score 8.197332832532052)
# New target (base this_period): 40.2141539785689
# CPU times: user 9.52 s, sys: 193 ms, total: 9.71 s
# Wall time: 9.79 s
# Processing new sequence (Period: 320; Drift: (0, 0); 26 past sequences).
# Major discrepancy between approx expected value 168.99999999999932 and actual value 256.0 for (10, 12) (distance 2; score 8.197332832532052)
# New target (base this_period): 258.9794709787575
# CPU times: user 9.38 s, sys: 201 ms, total: 9.58 s
# Wall time: 9.6 s
# Processing new sequence (Period: 320; Drift: (0, 0); 27 past sequences).
# Major discrepancy between approx expected value 168.99999999999932 and actual value 256.0 for (10, 12) (distance 2; score 8.197332832532052)
# New target (base this_period): 121.97061145516454
# CPU times: user 9.48 s, sys: 205 ms, total: 9.69 s
# Wall time: 9.71 s
# Processing new sequence (Period: 320; Drift: (0, 0); 28 past sequences).
# Major discrepancy between approx expected value 169.0 and actual value 256.0 for (10, 12) (distance 2; score 8.197332832532052)
# New target (base this_period): 176.45886024726042
# CPU times: user 9.2 s, sys: 195 ms, total: 9.4 s
# Wall time: 9.41 s
# Processing new sequence (Period: 320; Drift: (0, 0); 29 past sequences).
# Major discrepancy between approx expected value 168.99999999999886 and actual value 256.0 for (10, 12) (distance 2; score 8.197332832532052)
# New target (base this_period): 70.54415428131233
# CPU times: user 9.16 s, sys: 191 ms, total: 9.35 s
# Wall time: 9.36 s
# Processing new sequence (Period: 320; Drift: (0, 0); 30 past sequences).
# Major discrepancy between approx expected value 168.9999999999991 and actual value 256.0 for (10, 12) (distance 2; score 8.197332832532052)
# New target (base this_period): 131.92614221519034
# CPU times: user 9.09 s, sys: 192 ms, total: 9.28 s
# Wall time: 9.31 s
# Processing new sequence (Period: 320; Drift: (0, 0); 31 past sequences).
# Major discrepancy between approx expected value 168.99999999999932 and actual value 256.0 for (10, 12) (distance 2; score 8.197332832532052)
# New target (base this_period): 232.12367079705928
# CPU times: user 9.18 s, sys: 182 ms, total: 9.36 s
# Wall time: 9.37 s
# Processing new sequence (Period: 320; Drift: (0, 0); 32 past sequences).
# Major discrepancy between approx expected value 168.99999999999955 and actual value 256.0 for (10, 12) (distance 2; score 8.197332832532052)
# New target (base this_period): 197.8685831210305
# CPU times: user 9.61 s, sys: 191 ms, total: 9.8 s
# Wall time: 9.83 s
# Processing new sequence (Period: 320; Drift: (0, 0); 33 past sequences).
# Major discrepancy between approx expected value 168.99999999999932 and actual value 256.0 for (10, 12) (distance 2; score 8.197332832532052)
# New target (base this_period): 43.576382371159525
# CPU times: user 9.49 s, sys: 205 ms, total: 9.69 s
# Wall time: 9.71 s
# Processing new sequence (Period: 320; Drift: (0, 0); 34 past sequences).

# %% [markdown]
# ## Normalise Computed Results
#
# Same as done for human scorers above.

# %%
if relative_to_manual:
    for alg in algorithms:
        results[alg] = results[alg]-means
        # Boundary wrapping
        results.loc[results[alg]<-np.pi,alg] += 2*np.pi
        results.loc[results[alg]>np.pi,alg] -= 2*np.pi
        display(results.dropna(how='any',subset=scorers))
    
print('Fin')

# %%
display(results.dropna(how='any',subset=scorers).describe())
display(results.dropna(how='any',subset=scorers))

# %% [markdown]
# ## Combine and Melt Dataframes
#
# This makes plotting easier with Seaborn.

# %%
# Melt arrays for easier plotting
# but drop times we don't have manual results for
resultsMelted = results.dropna(how='any',subset=scorers).reset_index(level='Number')

if relative_to_manual:
    humansMelted = resultsMelted.melt(id_vars=['Number'], var_name='Scorer', value_vars=scorers, value_name='Frame')
    humansMelted = humansMelted.dropna()

algorithmsMelted = resultsMelted.melt(id_vars=['Number'], var_name='Algorithm', value_vars=algorithms, value_name='Frame')
algorithmsMelted = algorithmsMelted.dropna()

print('Fin')

# %% [markdown]
# ## Plots

# %%
# Plot Main Result
with sns.plotting_context("talk"):
    f, ax = plt.subplots(1)
    
    if relative_to_manual:
        sns.lineplot(x='Number',y='Frame', data=humansMelted, estimator='mean', err_kws={'alpha':0.5}, ax=ax)
    sns.lineplot(x='Number',y='Frame', hue='Algorithm', data=algorithmsMelted, sizes=50, ax=ax)
    
    ax.set_xlim([resultsMelted['Number'].values[0], resultsMelted['Number'].values[-1]+1])
    ax.set_xlabel('Number')
    if relative_to_manual:
        pass
#         ax.set_ylim([-np.pi,np.pi])  # Set to pass to zoom in
    ax.set_ylabel('Phase Difference/radians')
 
    sns.despine(ax=ax)

print('Fin')
